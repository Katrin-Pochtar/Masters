# %%
import pandas as pd
import numpy as np

# %%
arr1 = np.array((18, 14, 23, 36))
arr2 = np.array((12, 1, 4, 7))

# %%
np.add(arr1, arr2)
# Out:
# array([30, 15, 27, 43])

# %%
np.array([1, 2, 3, 4, 5, 6]).reshape(3,2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
np.array([1, 2, 3, 4, 5, 6]).reshape(1,6)
# Out:
# array([[1, 2, 3, 4, 5, 6]])

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'Los Angeles', 'New York', 'Houston']
}

# Create DataFrame
df = pd.DataFrame(data)

# %%
df['Age'].unique()
# Out:
# array([25, 30, 35, 40])

# %%
aggregated = df.groupby('City').agg({'Age': ['mean', 'sum', 'std', 'prod', 'count']})
print(aggregated)
# Out:
#               Age
#              mean sum       std prod count
# City
# Houston      40.0  40       NaN   40     1
# Los Angeles  30.0  30       NaN   30     1
# New York     30.0  60  7.071068  875     2

# %%
25*35
# Out:
# 875

# %%
type(df['Age'].unique())
# Out:
# numpy.ndarray

# %%
np.array([1, 2, 3, 4, 5, 6]).reshape(6,1)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6]])

# %%
arr1 + arr2
# Out:
# array([30, 15, 27, 43])

# %%
sum(arr1, arr2)
# Out:
# array([103,  92,  95,  98])

# %%
type(np.array([18, 14, 23, 36]))
# Out:
# numpy.ndarray

# %%
type(np.array((18, 14, 23, 36)))
# Out:
# numpy.ndarray

# %%
def mnk(x_, y_):
    # Находим количество точек
    n = len(x_)
    
    # Рассчитываем необходимые суммы
    sum_x = np.sum(x_)
    sum_y = np.sum(y_)
    sum_xy = np.sum(x_ * y_)
    sum_xx = np.sum(x_ * x_)
    
    # Рассчитываем коэффициенты a и b
    a = (n * sum_xy - sum_x * sum_y) / (n * sum_xx - sum_x**2)
    b = (sum_y - a * sum_x) / n
    
    return a, b

# Пример использования
x_ = np.linspace(0, 10, 30)  # временной ряд x длиной 30 точек
y_ = 3 * x_ + 2              # временной ряд y с коэффициентами a = 3, b = 2

# Находим коэффициенты a и b
a, b = mnk(x_, y_)
print("a:", a)
print("b:", b)
# Out:
# a: 3.0000000000000013
# b: 1.9999999999999905

# %%
Cars = pd.read_csv('Electric_Car.csv')

# %%
Cars.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
Carsgroupby = Cars.groupby('Brand').agg({'PriceEuro':'mean'})
Carsgroupby
# Out:
#                  PriceEuro
# Brand
# Aiways        36057.000000
# Audi          80593.666667
# BMW           53145.750000
# Byton         59833.333333
# CUPRA         45000.000000
# Citroen       40000.000000
# DS            37422.000000
# Fiat          36400.000000
# Ford          54568.750000
# Honda         34459.000000
# Hyundai       36408.333333
# Jaguar        75351.000000
# Kia           35862.400000
# Lexus         50000.000000
# Lightyear    149000.000000
# Lucid        105000.000000
# MG            30000.000000
# Mazda         32646.000000
# Mercedes      61705.000000
# Mini          31681.000000
# Nissan        45902.125000
# Opel          35350.666667
# Peugeot       32021.500000
# Polestar      56440.000000
# Porsche      138265.800000
# Renault       31268.200000
# SEAT          20129.000000
# Skoda         38255.666667
# Smart         22660.666667
# Sono          25500.000000
# Tesla         80272.307692
# Volkswagen    34602.375000
# Volvo         60437.000000

# %%
Cars_speed = Cars[(Cars['PriceEuro'] > 50000) & (Cars['TopSpeed_KmH'] > 200)].reset_index(drop=True)
Cars_speed

# Сделайте срез по столбцу PriceEuro со значениями более 50000 и по столбцу TopSpeed_KmH со значениями более 200.
# Переназначьте индексы таблицы начиная с нуля.
# Сохраните результаты проделанных действий в датафрейм с именем Cars_speed.
# Out:
#         Brand                           Model  AccelSec  TopSpeed_KmH  \
# 0      Tesla    Model 3 Long Range Dual Motor       4.6           233
# 1   Polestar                                2       4.7           210
# 2      Lucid                             Air        2.8           250
# 3    Porsche                   Taycan Turbo S       2.8           260
# 4      Tesla    Model Y Long Range Dual Motor       5.1           217
# 5       Audi                       e-tron GT        3.5           240
# 6      Tesla   Model 3 Long Range Performance       3.4           261
# 7      Tesla             Cybertruck Tri Motor       3.0           210
# 8      Tesla               Model S Long Range       3.8           250
# 9    Porsche                        Taycan 4S       4.0           250
# 10     Tesla                        Roadster        2.1           410
# 11     Tesla               Model X Long Range       4.6           250
# ...
